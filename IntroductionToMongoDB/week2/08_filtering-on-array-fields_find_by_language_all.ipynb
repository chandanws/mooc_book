# %%
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

client = MongoClient('mongodb://analytics:analytics-password@mflix-shard-00-00-mz7dv.mongodb.net:27017, mflix-shard-00-01-mz7dv.mongodb.net:27017, mflix-shard-00-02-mz7dv.mongodb.net:27017/?ssl=true&replicaSet=mflix-shard-0&authSource=admin')


filter = {
    'languages': {'$all': ['Korean', 'English']}
}

projection = {
    '_id' : 0,
    'title': 1,
    'languages': 1
}

clear_output()
pprint.pprint(list(client.mflix.movies.find(filter, projection)))
# Out:
# [{'languages': ['English', 'Korean'], 'title': 'Battle Hymn'},
#  {'languages': ['English', 'Korean'], 'title': 'Time Limit'},
#  {'languages': ['English', 'Korean'], 'title': 'The Great Impostor'},
#  {'languages': ['English', 'Japanese', 'Korean'], 'title': 'MASH'},
#  {'languages': ['English', 'Korean'], 'title': 'The Kentucky Fried Movie'},
#  {'languages': ['English', 'Korean', 'Spanish', 'Japanese', 'Latin'],
#   'title': 'Trouble in Mind'},
#  {'languages': ['English', 'Korean'], 'title': 'The Perfect Weapon'},
#  {'languages': ['English', 'Spanish', 'Korean'], 'title': 'Falling Down'},
#  {'languages': ['English', 'German', 'Korean'], 'title': 'Pentathlon'},
#  {'languages': ['English', 'Korean', 'French'], 'title': 'Outbreak'},
#  {'languages': ['English', 'French', 'Spanish', 'Korean'],
#   'title': 'Eye for an Eye'},
#  {'languages': ['English', 'Korean'], 'title': 'Deep Rising'},
#  {'languages': ['English', 'Korean'], 'title': 'Yellow'},
#  {'languages': ['English', 'Korean'], 'title': 'Provocateur'},
#  {'languages': ['English', 'Russian', 'Spanish', 'Korean'],
#   'title': 'Training Day'},
#  {'languages': ['English', 'Spanish', 'Korean'],
#   'title': 'La Ciudad (The City)'},
#  {'languages': ['English', 'Spanish', 'Korean'],
#   'title': 'La Ciudad (The City)'},
#  {'languages': ['Korean', 'English'], 'title': 'Marine Battleground'},
#  {'languages': ['English', 'Korean'], 'title': 'First Person Plural'},
#  {'languages': ['English',
#                 'Korean',
#                 'Cantonese',
#                 'Spanish',
#                 'German',
#                 'Icelandic',
#                 'Italian'],
#   'title': 'Die Another Day'},
#  {'languages': ['English',
#                 'Russian',
#                 'French',
#                 'Arabic',
#                 'Korean',
#                 'German',
#                 'Japanese'],
#   'title': 'Rollerball'},
#  {'languages': ['Korean', 'English', 'German'],
#   'title': 'J.S.A.: Joint Security Area'},
#  {'languages': ['Korean', 'English'], 'title': 'Marine Battleground'},
#  {'languages': ['Cantonese',
#                 'Mandarin',
#                 'English',
#                 'Korean',
#                 'French',
#                 'Turkish'],
#   'title': 'The Accidental Spy'},
#  {'languages': ['Czech', 'German', 'French', 'English', 'Italian', 'Korean'],
#   'title': 'I Served the King of England'},
#  {'languages': ['Korean', 'English'], 'title': 'Address Unknown'},
#  {'languages': ['Korean', 'English'], 'title': 'My Sassy Girl'},
#  {'languages': ['Korean', 'English'], 'title': 'Guns & Talks'},
#  {'languages': ['Korean', 'English'], 'title': 'Hwasango'},
#  {'languages': ['English', 'Mandarin', 'Korean'],
#   'title': 'Cradle 2 the Grave'},
#  {'languages': ['Korean', 'English', 'Mandarin', 'Thai', 'Cantonese'],
#   'title': '3 Extremes II'},
#  {'languages': ['English', 'Korean'], 'title': 'Starsky & Hutch'},
#  {'languages': ['Korean', 'English'], 'title': 'Sky Blue'},
#  {'languages': ['Korean', 'English'], 'title': 'Memories of Murder'},
#  {'languages': ['Mandarin', 'Cantonese', 'English', 'Korean'],
#   'title': 'The Myth'},
#  {'languages': ['English', 'French', 'Klingon', 'Korean', 'Arabic'],
#   'title': 'Team America: World Police'},
#  {'languages': ['English', 'Korean'], 'title': 'Dragon Wars: D-War'},
#  {'languages': ['English', 'Persian', 'Spanish', 'Mandarin', 'Korean'],
#   'title': 'Crash'},
#  {'languages': ['Cantonese', 'Korean', 'English'], 'title': 'Star Runner'},
#  {'languages': ['Korean', 'English'], 'title': 'Please Teach Me English'},
#  {'languages': ['English', 'Korean', 'Russian', 'Spanish'], 'title': 'Stealth'},
#  {'languages': ['Korean', 'English'], 'title': 'My Little Bride'},
#  {'languages': ['English', 'Korean'], 'title': 'The Pacifier'},
#  {'languages': ['Japanese', 'Korean', 'English'],
#   'title': 'Fighter in the Wind'},
#  {'languages': ['English', 'Korean', 'French', 'Vietnamese'],
#   'title': 'R-Point'},
#  {'languages': ['French', 'English', 'Korean', 'Russian'],
#   'title': 'The Intruder'},
#  {'languages': ['English', 'Spanish', 'Korean'], 'title': 'Harsh Times'},
#  {'languages': ['Korean', 'English', 'Japanese'],
#   'title': 'Sympathy for Lady Vengeance'},
#  {'languages': ['Korean', 'English', 'Japanese'],
#   'title': 'Sympathy for Lady Vengeance'},
#  {'languages': ['English', 'Cantonese', 'Korean', 'Mandarin', 'Japanese'],
#   'title': 'Seoul Raiders'},
#  {'languages': ['English', 'Cantonese', 'Korean', 'Mandarin', 'Japanese'],
#   'title': 'Seoul Raiders'},
#  {'languages': ['Thai', 'English', 'Japanese', 'Korean'],
#   'title': 'Invisible Waves'},
#  {'languages': ['Korean', 'English'], 'title': 'The Host'},
#  {'languages': ['Korean', 'Mandarin', 'English'], 'title': 'Deiji'},
#  {'languages': ['Korean', 'English'], 'title': 'Crossing the Line'},
#  {'languages': ['Korean', 'English', 'Thai', 'Russian', 'Mandarin'],
#   'title': 'Typhoon'},
#  {'languages': ['Korean', 'English'], 'title': 'Battle Ground 625'},
#  {'languages': ['English', 'Spanish', 'Korean'], 'title': 'Crank'},
#  {'languages': ['Korean', 'English'], 'title': 'In Between Days'},
#  {'languages': ['English', 'Korean'],
#   'title': 'Behind Enemy Lines II: Axis of Evil'},
#  {'languages': ['Korean', 'English', 'French'], 'title': 'Thirst'},
#  {'languages': ['Korean', 'English', 'French'], 'title': 'Thirst'},
#  {'languages': ['Korean', 'English'], 'title': 'Never Forever'},
#  {'languages': ['English', 'Spanish', 'Armenian', 'Korean', 'Persian'],
#   'title': 'The Blue Hour'},
#  {'languages': ['English', 'Cantonese', 'Korean'],
#   'title': 'Pineapple Express'},
#  {'languages': ['English', 'Japanese', 'Korean'],
#   'title': 'White Light/Black Rain: The Destruction of Hiroshima and Nagasaki'},
#  {'languages': ['English', 'Korean', 'Persian', 'Spanish', 'Arabic'],
#   'title': 'Crossing Over'},
#  {'languages': ['English', 'Japanese', 'Korean'], 'title': 'Mr. Robin kkosigi'},
#  {'languages': ['English', 'Russian', 'Korean'], 'title': 'Salt'},
#  {'languages': ['English', 'Korean', 'Estonian'], 'title': 'Yes Man'},
#  {'languages': ['Danish', 'Korean', 'English'], 'title': 'Red Chapel'},
#  {'languages': ['Korean', 'Thai', 'English', 'Russian'],
#   'title': 'A Better Tomorrow'},
#  {'languages': ['English', 'Korean'], 'title': 'Make Yourself at Home'},
#  {'languages': ['Korean', 'English'], 'title': 'Tidal Wave'},
#  {'languages': ['Korean', 'French', 'English'], 'title': 'Night and Day'},
#  {'languages': ['English', 'Korean'], 'title': 'Kimjongilia'},
#  {'languages': ['Korean', 'English'], 'title': 'The Juche Idea'},
#  {'languages': ['English', 'Korean'], 'title': 'Red Dawn'},
#  {'languages': ['Korean', 'English'], 'title': 'The Housemaid'},
#  {'languages': ['English', 'Korean'], 'title': 'Intangible Asset Number 82'},
#  {'languages': ['German',
#                 'French',
#                 'English',
#                 'Spanish',
#                 'Croatian',
#                 'Italian',
#                 'Portuguese',
#                 'Russian',
#                 'Korean'],
#   'title': 'Pina'},
#  {'languages': ['Korean', 'English'], 'title': 'Castaway on the Moon'},
#  {'languages': ['Korean', 'English'], 'title': 'The Man from Nowhere'},
#  {'languages': ['English', 'French', 'Korean', 'German', 'Japanese', 'Spanish'],
#   'title': 'Food Matters'},
#  {'languages': ['English', 'French', 'Korean', 'German', 'Japanese', 'Spanish'],
#   'title': 'Food Matters'},
#  {'languages': ['English', 'Korean', 'Mandarin'], 'title': 'Man-choo'},
#  {'languages': ['Danish', 'English', 'Korean'],
#   'title': "Kim Jong-Il's Comedy Club"},
#  {'languages': ['Korean', 'English'], 'title': '71: Into the Fire'},
#  {'languages': ['Korean',
#                 'German',
#                 'Japanese',
#                 'Mandarin',
#                 'Russian',
#                 'English'],
#   'title': 'My Way'},
#  {'languages': ['English', 'Korean'], 'title': 'Tabloid'},
#  {'languages': ['English', 'Korean', 'French', 'Japanese', 'Czech'],
#   'title': 'Snowpiercer'},
#  {'languages': ['English',
#                 'Dutch',
#                 'Indonesian',
#                 'Mandarin',
#                 'Spanish',
#                 'Korean'],
#   'title': 'The Forgotten Space'},
#  {'languages': ['English', 'Korean'],
#   'title': "Good Luck Charlie, It's Christmas!"},
#  {'languages': ['English', 'Spanish', 'Japanese', 'German', 'French', 'Korean'],
#   'title': 'The ABCs of Death'},
#  {'languages': ['Korean', 'English', 'French'], 'title': 'In Another Country'},
#  {'languages': ['Korean', 'English'], 'title': 'The Front Line'},
#  {'languages': ['Korean', 'English', 'Tagalog'], 'title': 'The Taste of Money'},
#  {'languages': ['Korean', 'Japanese', 'English'], 'title': 'Spellbound'},
#  {'languages': ['Korean', 'English', 'Russian'], 'title': 'Doomsday Book'},
#  {'languages': ['English', 'Korean'], 'title': 'Olympus Has Fallen'},
#  {'languages': ['Korean', 'Cantonese', 'English', 'Mandarin', 'Japanese'],
#   'title': 'The Thieves'},
#  {'languages': ['Korean', 'English', 'Filipino'], 'title': 'Flu'},
#  {'languages': ['Korean', 'English', 'German'], 'title': 'The Berlin File'},
#  {'languages': ['Korean', 'English'], 'title': 'A Company Man'},
#  {'languages': ['French', 'English', 'Italian', 'Korean'],
#   'title': 'Lost Rivers'},
#  {'languages': ['English', 'Italian', 'Spanish', 'Korean'],
#   'title': 'Caffeinated'},
#  {'languages': ['Korean', 'English', 'French'], 'title': 'The Tower'},
#  {'languages': ['English', 'Korean', 'German'], 'title': 'Seoul Searching'},
#  {'languages': ['Korean', 'English'], 'title': "Nobody's Daughter Haewon"},
#  {'languages': ['English', 'Mandarin', 'Malay', 'Korean'],
#   'title': 'UnHung Hero'},
#  {'languages': ['Mandarin', 'Min Nan', 'Korean', 'English'],
#   'title': 'Will You Still Love Me Tomorrow?'},
#  {'languages': ['English', 'Korean'], 'title': 'The Interview'},
#  {'languages': ['Korean', 'French', 'English'], 'title': 'Jibeuro ganeun gil'},
#  {'languages': ['English', 'French', 'Spanish', 'Korean', 'Chinese'],
#   'title': 'Lucy'},
#  {'languages': ['English', 'French', 'Korean'], 'title': 'Twinsters'},
#  {'languages': ['Korean', 'English', 'Japanese', 'Cantonese', 'Mandarin'],
#   'title': 'Assassination'},
#  {'languages': ['English', 'Korean'], 'title': 'Eun-mil-han Yu-hok'},
#  {'languages': ['Korean', 'English'], 'title': 'The Drop Box'},
#  {'languages': ['Korean', 'English', 'Japanese'], 'title': 'Hill of Freedom'},
#  {'languages': ['Korean', 'English', 'German'], 'title': 'Ode to My Father'},
#  {'languages': ['Korean', 'English'], 'title': 'Okja'},
#  {'languages': ['Korean', 'Japanese', 'English'], 'title': 'Power/Rangers'},
#  {'languages': ['English', 'Korean'],
#   'title': "Dennis Rodman's Big Bang in PyongYang"},
#  {'languages': ['Korean', 'English'], 'title': 'Robot Sound'}]
