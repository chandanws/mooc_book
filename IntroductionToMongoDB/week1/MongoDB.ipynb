# %%
from pymongo import MongoClient
import pymongo
import pprint

client = MongoClient("mongodb://analytics:analytics-password@mflix-shard-00-00-mz7dv.mongodb.net:27017,mflix-shard-00-01-mz7dv.mongodb.net:27017,mflix-shard-00-02-mz7dv.mongodb.net:27017/mflix?ssl=true&replicaSet=mflix-shard-0&authSource=admin")

pipeline = [
    {
        # group stage
        '$group':{
            '_id':{"language": "$language"},
            "count": {'$sum':1}
        }
    }
]

pprint.pprint(list(client.cluster0.movies_initial.aggregate(pipeline)))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-1-a0ee07330d99> in <module>()
#      15 ]
#      16
# ---> 17 pprint.pprint(list(client.cluster0.movies_initial.aggregate(pipeline)))
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in aggregate(self, pipeline, **kwargs)
#    1843         # If the server does not support the "cursor" option we
#    1844         # ignore useCursor and batchSize.
# -> 1845         with self._socket_for_reads() as (sock_info, slave_ok):
#    1846             if sock_info.max_wire_version > 0:
#    1847                 if use_cursor:
#
# ~/anaconda3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ...
